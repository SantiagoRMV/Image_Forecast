# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import LSTM, Dense, Reshape, Flatten, Conv2D, TimeDistributed

# %%
# Parámetros 
future_steps = 6
height, width, channels = 480, 480, 3

# %%
# Obtener el número total de imágenes
image_folder = '../data/Images_test'
forecast_folder = '../data/Images_Forecast'
os.makedirs(forecast_folder, exist_ok=True)  # Crear el folder 'Images/Forecast' si no existe
image_files = sorted([f'..data/Images_test/{i}' for i in os.listdir(image_folder) if i.endswith('.jpg')])
sequence_length = 138

if sequence_length <= 0:
    raise ValueError("No hay suficientes imágenes para formar secuencias con los parámetros dados.")

print(f"Número total de archivos de imagen: {len(image_files)}")
print(f"sequence_length: {sequence_length}, future_steps: {future_steps}")
# Out:
# Número total de archivos de imagen: 114
# sequence_length: 138, future_steps: 6

# %%
image_files
# Out:
# ['..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701050021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701051021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701052021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701053021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701054021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701055021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701060021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701061021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701062021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701063021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701064021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701065021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701070021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701071021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701072021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701073021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701074021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701075021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701080021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701081021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701082021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701083021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701084021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701085021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701090021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701091021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701092021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701093021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701094021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701095021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701100021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701101021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701102021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701103021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701104021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701105021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701110021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701111021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701112021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701113021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701114021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701115021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701120021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701121021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701122021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701123021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701124021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701125021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701130021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701131021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701132021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701133021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701134021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701135021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701140021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701141021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701142021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701143021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701144021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701145021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701150021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701151021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701152021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701153021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701154021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701155021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701160021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701161021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701162021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701163021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701164021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701165021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701170021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701171021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701172021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701173021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701174021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701175021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701180021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701181021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701182021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701183021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701184021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701185021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701190021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701191021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701192021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701193021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701194021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701195021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701200021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701201021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701202021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701203021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701204021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701205021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701210021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701211021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701212021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701213021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701214021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701215021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701220021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701221021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701222021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701223021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701224021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701225021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701230021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701231021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701232021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701233021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701234021.jpg',
#  '..data/Images_test/OR_ABI-L2-ACMF-M6_G16_s20230701235021.jpg']

# %%
# Función para cargar y preprocesar imágenes
def load_and_preprocess_image(image_path, target_size=(height, width)):
    image = cv2.imread(image_path)
    if image is None:
        raise FileNotFoundError(f"No se puede leer la imagen: {image_path}")
    image = cv2.resize(image, target_size)
    image = image.astype('float32') / 255.0  # Normalizacion RGB
    return image

# Función para cargar secuencias de imágenes
def load_image_sequences(folder, sequence_length, future_steps, image_files):
    X = []
    y = []
    
    for i in range(0, len(image_files) - sequence_length - future_steps + 1):
        sequence_images = []
        future_images = []

        for j in range(sequence_length):
            image_path = image_files[i + j]
            image = load_and_preprocess_image(image_path, target_size=(height, width))
            sequence_images.append(image)

        for k in range(sequence_length, sequence_length + future_steps):
            image_path = image_files[i + k]
            image = load_and_preprocess_image(image_path, target_size=(height, width))
            future_images.append(image)

        X.append(sequence_images)
        y.append(future_images)

    return np.array(X), np.array(y)

# %%
X
# Out:
# array([], dtype=float64)

# %%
# Cargar secuencias de imágenes
X, y = load_image_sequences(image_folder, sequence_length, future_steps, image_files)

if X.size == 0 or y.size == 0:
    print("No se encontraron secuencias de imágenes válidas.")
else:
    # Extraer features usando VGG16
    base_model = VGG16(weights='imagenet', include_top=False, input_shape=(height, width, channels))
    flatten_layer = Flatten()(base_model.output)
    feature_extractor = Model(inputs=base_model.input, outputs=flatten_layer)

    def extract_features(image_sequences):
        num_sequences = image_sequences.shape[0]
        features = np.zeros((num_sequences, sequence_length, feature_extractor.output_shape[1]))

        for i in range(num_sequences):
            for j in range(sequence_length):
                image = image_sequences[i, j]
                image = np.expand_dims(image, axis=0)  # Añadir dimensión del lote
                feature = feature_extractor.predict(image)
                features[i, j] = feature.squeeze()
        return features

    X_features = extract_features(X)

    # Modelo LSTM
    model = Sequential()
    model.add(LSTM(256, input_shape=(sequence_length, feature_extractor.output_shape[1]), return_sequences=True))
    model.add(LSTM(128, return_sequences=False))
    model.add(Dense(future_steps * height * width * channels, activation='linear'))
    model.add(Reshape((future_steps, height, width, channels)))

    model.compile(optimizer='adam', loss='mse')
    model.summary()

    # Entrenar el modelo (ajustar validation_split si hay pocas muestras)
    validation_split = 0.2 if X_features.shape[0] > 1 else 0.0
    if validation_split > 0:
        history = model.fit(X_features, y, epochs=30, batch_size=32, validation_split=validation_split)
    else:
        history = model.fit(X_features, y, epochs=30, batch_size=32)

    # Realizar predicciones
    def make_predictions(model, X_features):
        y_pred = model.predict(X_features)
        return y_pred

    # Guardar imágenes futuras
    def save_images(images, folder, original_filenames, suffix='_pred'):
        num_sequences, future_steps, height, width, channels = images.shape
        for i in range(num_sequences):
            for j in range(future_steps):
                image = images[i, j]
                original_filename = os.path.basename(original_filenames[i + sequence_length + j])  # Extraer solo el nombre de archivo
                base, ext = os.path.splitext(original_filename)
                new_filename = f"{base}{suffix}{ext}"
                new_filepath = os.path.join(folder, new_filename)
                image = (image * 255).astype('uint8')  # Desnormalizar
                cv2.imwrite(new_filepath, image)
                print(f"Guardada imagen: {new_filepath}")


    # Obtener predicciones
    y_pred = make_predictions(model, X_features)

    # Guardar las imágenes futuras predichas en 'Images/Forecast'
    save_images(y_pred, forecast_folder, image_files)

    # Función para visualizar imágenes
    def mostrar_imagenes(imagenes, titulo):
        plt.figure(figsize=(12, 6))
        for i in range(imagenes.shape[0]):
            plt.subplot(1, imagenes.shape[0], i + 1)
            plt.imshow(imagenes[i])
            plt.axis('off')
        plt.suptitle(titulo)
        plt.show()

    # Visualizar algunas imágenes de entrada y predicciones
    indice_secuencia = 0  # Cambia este índice para visualizar diferentes secuencias
    mostrar_imagenes(X[indice_secuencia], titulo='Secuencia de Imágenes X')
    mostrar_imagenes(y[indice_secuencia], titulo='Imágenes Futuras y')
    mostrar_imagenes(y_pred[indice_secuencia], titulo='Predicciones del Modelo')
# Out:
# No se encontraron secuencias de imágenes válidas.
